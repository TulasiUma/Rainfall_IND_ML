# %%
import pandas as pd
import pickle
import warnings
warnings.filterwarnings("ignore")
data=pd.read_csv("C:/Users/umaac/OneDrive/Desktop/RainfallIND.csv")
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data.head(50)
# Out:
#                   SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN  \
# 0   ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8  517.5
# 1   ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1  537.1
# 2   ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1  479.9
# 3   ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5  495.1
# 4   ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5  628.7
# 5   ANDAMAN & NICOBAR ISLANDS  1906   36.6    0.0    0.0    0.0  556.1  733.3
# 6   ANDAMAN & NICOBAR ISLANDS  1907  110.7    0.0  113.3   21.6  616.3  305.2
# 7   ANDAMAN & NICOBAR ISLANDS  1908   20.9   85.1    0.0   29.0  562.0  693.6
# 8   ANDAMAN & NICOBAR ISLANDS  1910   26.6   22.7  206.3   89.3  224.5  472.7
# 9   ANDAMAN & NICOBAR ISLANDS  1911    0.0    8.4    0.0  122.5  327.3  649.0
# 10  ANDAMAN & NICOBAR ISLANDS  1912  583.7    0.8    0.0   21.9  140.7  549.8
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
list(data)
# Out:
# ['SUBDIVISION',
#  'YEAR',
#  'JAN',
#  'FEB',
#  'MAR',
#  'APR',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC',
#  'ANNUAL',
#  'Jan-Feb',
#  'Mar-May',
#  'Jun-Sep',
#  'Oct-Dec']

# %%
data.shape
# Out:
# (4116, 19)

# %%
data.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data1=data.drop(['ANNUAL','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],axis=1)
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.boxplot(data.JAN)
# plt.show()

# %%
# data1=data1.groupby(['SUBDIVISION']).count()
# data1

# %%
x = data1['SUBDIVISION'].unique().tolist()
for i in x:
    print(i)
    z = data1[data1['SUBDIVISION'] == i]
    print(z.isna().sum())
    print("#####################")
# Out:
# ANDAMAN & NICOBAR ISLANDS
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            2
# APR            2
# MAY            1
# JUN            2
# JUL            2
# AUG            2
# SEP            3
# OCT            2
# NOV            2
# DEC            3
# dtype: int64
# #####################
# ARUNACHAL PRADESH
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            1
# MAR            2
# APR            0
# MAY            0
# JUN            1
# JUL            1
# AUG            0
# SEP            0
# OCT            2
# NOV            2
# DEC            2
# dtype: int64
# #####################
# ASSAM & MEGHALAYA
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64
# #####################
# ...

# %%
data2=data1.loc[(data.SUBDIVISION=='ANDAMAN & NICOBAR ISLANDS')]
data2
# Out:
#                    SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY  \
# 0    ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8
# 1    ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1
# 2    ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1
# 3    ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5
# 4    ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5
# ..                         ...   ...    ...    ...    ...    ...    ...
# 105  ANDAMAN & NICOBAR ISLANDS  2011  265.9   84.8  272.8  111.4  326.5
# 106  ANDAMAN & NICOBAR ISLANDS  2012  119.9   45.6   30.9   55.8  533.9
# 107  ANDAMAN & NICOBAR ISLANDS  2013   67.1   37.6   43.0   46.3  509.3
# 108  ANDAMAN & NICOBAR ISLANDS  2014   41.9    8.6    0.0   11.1  238.0
# 109  ANDAMAN & NICOBAR ISLANDS  2015  126.8    7.6    3.1  138.2  331.9
#
#        JUN    JUL    AUG    SEP    OCT    NOV    DEC
# ...

# %%
data2.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            2
# APR            2
# MAY            1
# JUN            2
# JUL            2
# AUG            2
# SEP            3
# OCT            2
# NOV            2
# DEC            3
# dtype: int64

# %%
data2=data1.loc[(data.SUBDIVISION=='ANDAMAN & NICOBAR ISLANDS')]
data2
# Out:
#                    SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY  \
# 0    ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8
# 1    ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1
# 2    ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1
# 3    ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5
# 4    ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5
# ..                         ...   ...    ...    ...    ...    ...    ...
# 105  ANDAMAN & NICOBAR ISLANDS  2011  265.9   84.8  272.8  111.4  326.5
# 106  ANDAMAN & NICOBAR ISLANDS  2012  119.9   45.6   30.9   55.8  533.9
# 107  ANDAMAN & NICOBAR ISLANDS  2013   67.1   37.6   43.0   46.3  509.3
# 108  ANDAMAN & NICOBAR ISLANDS  2014   41.9    8.6    0.0   11.1  238.0
# 109  ANDAMAN & NICOBAR ISLANDS  2015  126.8    7.6    3.1  138.2  331.9
#
#        JUN    JUL    AUG    SEP    OCT    NOV    DEC
# ...

# %%
# data2=data2['JAN'].fillna((data2['JAN'].mean()), inplace=True)
# data2

# %%
data2['JAN'].fillna((data2['JAN'].mean()), inplace=True)
data2['FEB'].fillna((data2['FEB'].mean()), inplace=True)
data2['MAR'].fillna((data2['MAR'].mean()), inplace=True)
data2['APR'].fillna((data2['APR'].mean()), inplace=True)
data2['MAY'].fillna((data2['MAY'].mean()), inplace=True)
data2['JUN'].fillna((data2['JUN'].mean()), inplace=True)
data2['JUL'].fillna((data2['JUL'].mean()), inplace=True)
data2['AUG'].fillna((data2['AUG'].mean()), inplace=True)
data2['SEP'].fillna((data2['SEP'].mean()), inplace=True)
data2['OCT'].fillna((data2['OCT'].mean()), inplace=True)
data2['NOV'].fillna((data2['NOV'].mean()), inplace=True)
data2['DEC'].fillna((data2['DEC'].mean()), inplace=True)

# %%
data2
# Out:
#                    SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY  \
# 0    ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8
# 1    ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1
# 2    ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1
# 3    ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5
# 4    ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5
# ..                         ...   ...    ...    ...    ...    ...    ...
# 105  ANDAMAN & NICOBAR ISLANDS  2011  265.9   84.8  272.8  111.4  326.5
# 106  ANDAMAN & NICOBAR ISLANDS  2012  119.9   45.6   30.9   55.8  533.9
# 107  ANDAMAN & NICOBAR ISLANDS  2013   67.1   37.6   43.0   46.3  509.3
# 108  ANDAMAN & NICOBAR ISLANDS  2014   41.9    8.6    0.0   11.1  238.0
# 109  ANDAMAN & NICOBAR ISLANDS  2015  126.8    7.6    3.1  138.2  331.9
#
#        JUN    JUL    AUG    SEP    OCT    NOV    DEC
# ...

# %%
data2.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data3=data1.loc[(data.SUBDIVISION=='ARUNACHAL PRADESH')]
data3
# Out:
#            SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN  \
# 110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6  1124.9
# 111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9   823.8
# 112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1  1609.9
# 113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6   973.6
# 114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6   840.6
# ..                 ...   ...   ...    ...    ...    ...    ...     ...
# 202  ARUNACHAL PRADESH  2011  40.0   51.3  174.5  240.8  219.6   288.4
# 203  ARUNACHAL PRADESH  2012  57.8   35.8  134.2  403.4  187.4   645.8
# 204  ARUNACHAL PRADESH  2013  18.5   40.5  115.1  175.1  335.8   290.0
# 205  ARUNACHAL PRADESH  2014  19.0  101.9   80.3   86.7  299.0   415.8
# 206  ARUNACHAL PRADESH  2015  30.8   47.5   97.5  287.1  238.9   637.9
#
#         JUL    AUG    SEP    OCT   NOV   DEC
# 110     NaN  629.7  333.9    NaN   NaN   NaN
# ...

# %%
data3['JAN'].fillna((data3['JAN'].mean()), inplace=True)
data3['FEB'].fillna((data3['FEB'].mean()), inplace=True)
data3['MAR'].fillna((data3['MAR'].mean()), inplace=True)
data3['APR'].fillna((data3['APR'].mean()), inplace=True)
data3['MAY'].fillna((data3['MAY'].mean()), inplace=True)
data3['JUN'].fillna((data3['JUN'].mean()), inplace=True)
data3['JUL'].fillna((data3['JUL'].mean()), inplace=True)
data3['AUG'].fillna((data3['AUG'].mean()), inplace=True)
data3['SEP'].fillna((data3['SEP'].mean()), inplace=True)
data3['OCT'].fillna((data3['OCT'].mean()), inplace=True)
data3['NOV'].fillna((data3['NOV'].mean()), inplace=True)
data3['DEC'].fillna((data3['DEC'].mean()), inplace=True)
data3
# Out:
#            SUBDIVISION  YEAR   JAN    FEB         MAR    APR    MAY     JUN  \
# 110  ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1  424.6  1124.9
# 111  ARUNACHAL PRADESH  1917  21.4  164.5  153.527368  269.6  107.9   823.8
# 112  ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6  861.1  1609.9
# 113  ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9  420.6   973.6
# 114  ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7  173.6   840.6
# ..                 ...   ...   ...    ...         ...    ...    ...     ...
# 202  ARUNACHAL PRADESH  2011  40.0   51.3  174.500000  240.8  219.6   288.4
# 203  ARUNACHAL PRADESH  2012  57.8   35.8  134.200000  403.4  187.4   645.8
# 204  ARUNACHAL PRADESH  2013  18.5   40.5  115.100000  175.1  335.8   290.0
# 205  ARUNACHAL PRADESH  2014  19.0  101.9   80.300000   86.7  299.0   415.8
# 206  ARUNACHAL PRADESH  2015  30.8   47.5   97.500000  287.1  238.9   637.9
#
# ...

# %%
data3.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data4=data1.loc[(data.SUBDIVISION=='JAMMU & KASHMIR')]
data4
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
#         AUG    SEP   OCT   NOV   DEC
# ...

# %%
data4['JAN'].fillna((data4['JAN'].mean()), inplace=True)
data4['FEB'].fillna((data4['FEB'].mean()), inplace=True)
data4['MAR'].fillna((data4['MAR'].mean()), inplace=True)
data4['APR'].fillna((data4['APR'].mean()), inplace=True)
data4['MAY'].fillna((data4['MAY'].mean()), inplace=True)
data4['JUN'].fillna((data4['JUN'].mean()), inplace=True)
data4['JUL'].fillna((data4['JUL'].mean()), inplace=True)
data4['AUG'].fillna((data4['AUG'].mean()), inplace=True)
data4['SEP'].fillna((data4['SEP'].mean()), inplace=True)
data4['OCT'].fillna((data4['OCT'].mean()), inplace=True)
data4['NOV'].fillna((data4['NOV'].mean()), inplace=True)
data4['DEC'].fillna((data4['DEC'].mean()), inplace=True)
data4
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
#         AUG    SEP   OCT   NOV   DEC
# ...

# %%
data4.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data5=data1.loc[(data.SUBDIVISION=='WEST MADHYA PRADESH')]
data5
# Out:
#               SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 2047  WEST MADHYA PRADESH  1901  25.8   5.8   5.8   2.8   2.1   41.2  228.9
# 2048  WEST MADHYA PRADESH  1902  22.1   8.4   0.0   2.0   5.9   35.9  401.9
# 2049  WEST MADHYA PRADESH  1903   5.3   0.0   0.0   0.0  22.3   50.6  304.9
# 2050  WEST MADHYA PRADESH  1904   3.2  15.5  14.8   0.0  12.0   96.6  273.0
# 2051  WEST MADHYA PRADESH  1905   3.5   4.4   1.1   0.8   3.0   36.1  326.3
# ...                   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 2157  WEST MADHYA PRADESH  2011   0.0   1.7   0.1   1.8   3.6  241.5  306.7
# 2158  WEST MADHYA PRADESH  2012   6.2   0.0   0.0   0.9   3.1   48.2  439.2
# 2159  WEST MADHYA PRADESH  2013   1.7  31.1   8.5   2.8   0.4  263.7  485.1
# 2160  WEST MADHYA PRADESH  2014  25.6  34.4   4.6   1.4   1.4   30.6  337.4
# 2161  WEST MADHYA PRADESH  2015  40.2   6.4  53.5  13.3   2.0  154.1  428.2
#
#         AUG    SEP   OCT   NOV   DEC
# ...

# %%
data5['JAN'].fillna((data5['JAN'].mean()), inplace=True)
data5['FEB'].fillna((data5['FEB'].mean()), inplace=True)
data5['MAR'].fillna((data5['MAR'].mean()), inplace=True)
data5['APR'].fillna((data5['APR'].mean()), inplace=True)
data5['MAY'].fillna((data5['MAY'].mean()), inplace=True)
data5['JUN'].fillna((data5['JUN'].mean()), inplace=True)
data5['JUL'].fillna((data5['JUL'].mean()), inplace=True)
data5['AUG'].fillna((data5['AUG'].mean()), inplace=True)
data5['SEP'].fillna((data5['SEP'].mean()), inplace=True)
data5['OCT'].fillna((data5['OCT'].mean()), inplace=True)
data5['NOV'].fillna((data5['NOV'].mean()), inplace=True)
data5['DEC'].fillna((data5['DEC'].mean()), inplace=True)
data5
# Out:
#               SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 2047  WEST MADHYA PRADESH  1901  25.8   5.8   5.8   2.8   2.1   41.2  228.9
# 2048  WEST MADHYA PRADESH  1902  22.1   8.4   0.0   2.0   5.9   35.9  401.9
# 2049  WEST MADHYA PRADESH  1903   5.3   0.0   0.0   0.0  22.3   50.6  304.9
# 2050  WEST MADHYA PRADESH  1904   3.2  15.5  14.8   0.0  12.0   96.6  273.0
# 2051  WEST MADHYA PRADESH  1905   3.5   4.4   1.1   0.8   3.0   36.1  326.3
# ...                   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 2157  WEST MADHYA PRADESH  2011   0.0   1.7   0.1   1.8   3.6  241.5  306.7
# 2158  WEST MADHYA PRADESH  2012   6.2   0.0   0.0   0.9   3.1   48.2  439.2
# 2159  WEST MADHYA PRADESH  2013   1.7  31.1   8.5   2.8   0.4  263.7  485.1
# 2160  WEST MADHYA PRADESH  2014  25.6  34.4   4.6   1.4   1.4   30.6  337.4
# 2161  WEST MADHYA PRADESH  2015  40.2   6.4  53.5  13.3   2.0  154.1  428.2
#
#         AUG    SEP   OCT   NOV   DEC
# ...

# %%
data5.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data6=data1.loc[(data.SUBDIVISION=='LAKSHADWEEP')]
data6
# Out:
#       SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 4002  LAKSHADWEEP  1901  22.6  86.4  114.8  263.8   37.3  459.0    0.0    0.0
# 4003  LAKSHADWEEP  1902  99.3   9.6   32.6   40.4  179.1  374.2  413.3  170.0
# 4004  LAKSHADWEEP  1903  63.5  95.0    0.0   29.5  144.1  212.4  261.8  202.0
# 4005  LAKSHADWEEP  1904   0.0   0.0   13.5   13.2  143.3  261.3  256.0   38.9
# 4006  LAKSHADWEEP  1905  62.4   0.0    0.0    0.0  166.7  400.7   68.7  377.5
# ...           ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 4111  LAKSHADWEEP  2011   5.1   2.8    3.1   85.9  107.2  153.6  350.2  254.0
# 4112  LAKSHADWEEP  2012  19.2   0.1    1.6   76.8   21.2  327.0  231.5  381.2
# 4113  LAKSHADWEEP  2013  26.2  34.4   37.5    5.3   88.3  426.2  296.4  154.4
# 4114  LAKSHADWEEP  2014  53.2  16.1    4.4   14.9   57.4  244.1  116.1  466.1
# 4115  LAKSHADWEEP  2015   2.2   0.5    3.7   87.1  133.1  296.6  257.5  146.4
#
#         SEP    OCT    NOV    DEC
# ...

# %%
data6['JAN'].fillna((data6['JAN'].mean()), inplace=True)
data6['FEB'].fillna((data6['FEB'].mean()), inplace=True)
data6['MAR'].fillna((data6['MAR'].mean()), inplace=True)
data6['APR'].fillna((data6['APR'].mean()), inplace=True)
data6['MAY'].fillna((data6['MAY'].mean()), inplace=True)
data6['JUN'].fillna((data6['JUN'].mean()), inplace=True)
data6['JUL'].fillna((data6['JUL'].mean()), inplace=True)
data6['AUG'].fillna((data6['AUG'].mean()), inplace=True)
data6['SEP'].fillna((data6['SEP'].mean()), inplace=True)
data6['OCT'].fillna((data6['OCT'].mean()), inplace=True)
data6['NOV'].fillna((data6['NOV'].mean()), inplace=True)
data6['DEC'].fillna((data6['DEC'].mean()), inplace=True)
data6
# Out:
#       SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 4002  LAKSHADWEEP  1901  22.6  86.4  114.8  263.8   37.3  459.0    0.0    0.0
# 4003  LAKSHADWEEP  1902  99.3   9.6   32.6   40.4  179.1  374.2  413.3  170.0
# 4004  LAKSHADWEEP  1903  63.5  95.0    0.0   29.5  144.1  212.4  261.8  202.0
# 4005  LAKSHADWEEP  1904   0.0   0.0   13.5   13.2  143.3  261.3  256.0   38.9
# 4006  LAKSHADWEEP  1905  62.4   0.0    0.0    0.0  166.7  400.7   68.7  377.5
# ...           ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 4111  LAKSHADWEEP  2011   5.1   2.8    3.1   85.9  107.2  153.6  350.2  254.0
# 4112  LAKSHADWEEP  2012  19.2   0.1    1.6   76.8   21.2  327.0  231.5  381.2
# 4113  LAKSHADWEEP  2013  26.2  34.4   37.5    5.3   88.3  426.2  296.4  154.4
# 4114  LAKSHADWEEP  2014  53.2  16.1    4.4   14.9   57.4  244.1  116.1  466.1
# 4115  LAKSHADWEEP  2015   2.2   0.5    3.7   87.1  133.1  296.6  257.5  146.4
#
# ...

# %%
data6.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data7=data1.loc[(data.SUBDIVISION=='COASTAL KARNATAKA')]
data7
# Out:
#             SUBDIVISION  YEAR  JAN   FEB   MAR   APR    MAY     JUN     JUL  \
# 3542  COASTAL KARNATAKA  1901  1.8   0.6  10.7  52.4   81.6   960.9   991.2
# 3543  COASTAL KARNATAKA  1902  3.2   0.3   4.9  10.2   54.6   698.4  1401.6
# 3544  COASTAL KARNATAKA  1903  0.7   0.0   0.0   4.1  202.8   536.5  1405.5
# 3545  COASTAL KARNATAKA  1904  2.4   0.0   4.8  23.7   93.2  1108.2  1070.0
# 3546  COASTAL KARNATAKA  1905  0.0   0.2   0.0   6.4   83.1   767.3   777.3
# ...                 ...   ...  ...   ...   ...   ...    ...     ...     ...
# 3652  COASTAL KARNATAKA  2011  4.8   3.8   8.7  66.1   49.3  1018.4  1080.5
# 3653  COASTAL KARNATAKA  2012  NaN  11.4   5.1  77.0   22.9   650.9   754.6
# 3654  COASTAL KARNATAKA  2013  2.4  19.6  19.0  28.5  100.4  1153.0  1515.3
# 3655  COASTAL KARNATAKA  2014  0.0   0.3   1.9  40.5  181.9   507.0  1155.4
# 3656  COASTAL KARNATAKA  2015  1.4   1.0  32.3  72.2  150.3   735.3   930.9
#
#          AUG    SEP    OCT    NOV    DEC
# ...

# %%
data7['JAN'].fillna((data7['JAN'].mean()), inplace=True)
data7['FEB'].fillna((data7['FEB'].mean()), inplace=True)
data7['MAR'].fillna((data7['MAR'].mean()), inplace=True)
data7['APR'].fillna((data7['APR'].mean()), inplace=True)
data7['MAY'].fillna((data7['MAY'].mean()), inplace=True)
data7['JUN'].fillna((data7['JUN'].mean()), inplace=True)
data7['JUL'].fillna((data7['JUL'].mean()), inplace=True)
data7['AUG'].fillna((data7['AUG'].mean()), inplace=True)
data7['SEP'].fillna((data7['SEP'].mean()), inplace=True)
data7['OCT'].fillna((data7['OCT'].mean()), inplace=True)
data7['NOV'].fillna((data7['NOV'].mean()), inplace=True)
data7['DEC'].fillna((data7['DEC'].mean()), inplace=True)
data7
# Out:
#             SUBDIVISION  YEAR       JAN   FEB   MAR   APR    MAY     JUN  \
# 3542  COASTAL KARNATAKA  1901  1.800000   0.6  10.7  52.4   81.6   960.9
# 3543  COASTAL KARNATAKA  1902  3.200000   0.3   4.9  10.2   54.6   698.4
# 3544  COASTAL KARNATAKA  1903  0.700000   0.0   0.0   4.1  202.8   536.5
# 3545  COASTAL KARNATAKA  1904  2.400000   0.0   4.8  23.7   93.2  1108.2
# 3546  COASTAL KARNATAKA  1905  0.000000   0.2   0.0   6.4   83.1   767.3
# ...                 ...   ...       ...   ...   ...   ...    ...     ...
# 3652  COASTAL KARNATAKA  2011  4.800000   3.8   8.7  66.1   49.3  1018.4
# 3653  COASTAL KARNATAKA  2012  1.937719  11.4   5.1  77.0   22.9   650.9
# 3654  COASTAL KARNATAKA  2013  2.400000  19.6  19.0  28.5  100.4  1153.0
# 3655  COASTAL KARNATAKA  2014  0.000000   0.3   1.9  40.5  181.9   507.0
# 3656  COASTAL KARNATAKA  2015  1.400000   1.0  32.3  72.2  150.3   735.3
#
#          JUL     AUG    SEP    OCT    NOV    DEC
# ...

# %%
data7.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
# x = data1['SUBDIVISION'].unique().tolist()
# for i in x:
#     print(i)
#     z = data1[data1['SUBDIVISION'] == i]
#     print(z.isna().sum())
#     print("#####################")

# %%
data8=pd.concat([data2,data3,data4,data5,data6,data7])
data8
# Out:
#                     SUBDIVISION  YEAR        JAN    FEB   MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.200000   87.1  29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.000000  159.8  12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.700000  144.0   0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.400000   14.7   0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.300000    0.0   3.3   26.9  279.5
# ...                         ...   ...        ...    ...   ...    ...    ...
# 3652          COASTAL KARNATAKA  2011   4.800000    3.8   8.7   66.1   49.3
# 3653          COASTAL KARNATAKA  2012   1.937719   11.4   5.1   77.0   22.9
# 3654          COASTAL KARNATAKA  2013   2.400000   19.6  19.0   28.5  100.4
# 3655          COASTAL KARNATAKA  2014   0.000000    0.3   1.9   40.5  181.9
# 3656          COASTAL KARNATAKA  2015   1.400000    1.0  32.3   72.2  150.3
#
#          JUN     JUL     AUG    SEP    OCT    NOV    DEC
# ...

# %%
null_state=['ANDAMAN & NICOBAR ISLANDS','ARUNACHAL PRADESH','JAMMU & KASHMIR','WEST MADHYA PRADESH','COASTAL KARNATAKA','LAKSHADWEEP']
cols=['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
for i in null_state:
    z=data1[data1['SUBDIVISION']== i]
    for j in cols:
        col_mean= z[j].mean()
        z[j].fillna(col_mean,inplace=True)
    data1.update(z)
print(data1.shape)
print(data1.isna().sum())
data1.head()
# Out:
# (4116, 14)
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC
# 0  365.1  481.1  332.6  388.5  558.2   33.6
# 1  228.9  753.7  666.2  197.2  359.0  160.5
# 2  728.4  326.7  339.0  181.2  284.4  225.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1
# ...

# %%
A=data1[ (data1['SUBDIVISION']=='KERALA') | (data1['SUBDIVISION']=='EAST RAJASTHAN') | (data1['SUBDIVISION']=='WEST RAJASTHAN') | (data1['SUBDIVISION']=='ARUNACHAL PRADESH')]
A
# Out:
#             SUBDIVISION  YEAR   JAN    FEB         MAR    APR    MAY     JUN  \
# 110   ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1  424.6  1124.9
# 111   ARUNACHAL PRADESH  1917  21.4  164.5  153.527368  269.6  107.9   823.8
# 112   ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6  861.1  1609.9
# 113   ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9  420.6   973.6
# 114   ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7  173.6   840.6
# ...                 ...   ...   ...    ...         ...    ...    ...     ...
# 3997             KERALA  2011  20.5   45.7   24.100000  165.2  124.2   788.5
# 3998             KERALA  2012   7.4   11.0   21.000000  171.1   95.3   430.3
# 3999             KERALA  2013   3.9   40.1   49.900000   49.3  119.3  1042.7
# 4000             KERALA  2014   4.6   10.3   17.900000   95.7  251.0   454.4
# 4001             KERALA  2015   3.1    5.8   50.100000  214.1  201.8   563.6
#
# ...

# %%
A['JJAS']=A.apply(lambda row:row.JUN + row.JUL + row.AUG + row.SEP,axis=1)#JJAS=jun,jul,aug,sep
A
# Out:
#             SUBDIVISION  YEAR   JAN    FEB         MAR    APR    MAY     JUN  \
# 110   ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1  424.6  1124.9
# 111   ARUNACHAL PRADESH  1917  21.4  164.5  153.527368  269.6  107.9   823.8
# 112   ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6  861.1  1609.9
# 113   ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9  420.6   973.6
# 114   ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7  173.6   840.6
# ...                 ...   ...   ...    ...         ...    ...    ...     ...
# 3997             KERALA  2011  20.5   45.7   24.100000  165.2  124.2   788.5
# 3998             KERALA  2012   7.4   11.0   21.000000  171.1   95.3   430.3
# 3999             KERALA  2013   3.9   40.1   49.900000   49.3  119.3  1042.7
# 4000             KERALA  2014   4.6   10.3   17.900000   95.7  251.0   454.4
# 4001             KERALA  2015   3.1    5.8   50.100000  214.1  201.8   563.6
#
# ...

# %%
A['OND']=A.apply(lambda row:row.OCT + row.NOV + row.DEC ,axis=1)#OND=oct,nov,dec
A
# Out:
#             SUBDIVISION  YEAR   JAN    FEB         MAR    APR    MAY     JUN  \
# 110   ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1  424.6  1124.9
# 111   ARUNACHAL PRADESH  1917  21.4  164.5  153.527368  269.6  107.9   823.8
# 112   ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6  861.1  1609.9
# 113   ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9  420.6   973.6
# 114   ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7  173.6   840.6
# ...                 ...   ...   ...    ...         ...    ...    ...     ...
# 3997             KERALA  2011  20.5   45.7   24.100000  165.2  124.2   788.5
# 3998             KERALA  2012   7.4   11.0   21.000000  171.1   95.3   430.3
# 3999             KERALA  2013   3.9   40.1   49.900000   49.3  119.3  1042.7
# 4000             KERALA  2014   4.6   10.3   17.900000   95.7  251.0   454.4
# 4001             KERALA  2015   3.1    5.8   50.100000  214.1  201.8   563.6
#
# ...

# %%
A['ANNUAL_RAIN_fall']=A.apply(lambda row: row.JAN + row.FEB + row.MAR + row.APR + row.MAY + row.JUN + row.JUL + row.AUG + row.SEP + row.OCT + row.NOV + row.DEC,axis=1)
A
# Out:
#             SUBDIVISION  YEAR   JAN    FEB         MAR    APR    MAY     JUN  \
# 110   ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1  424.6  1124.9
# 111   ARUNACHAL PRADESH  1917  21.4  164.5  153.527368  269.6  107.9   823.8
# 112   ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6  861.1  1609.9
# 113   ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9  420.6   973.6
# 114   ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7  173.6   840.6
# ...                 ...   ...   ...    ...         ...    ...    ...     ...
# 3997             KERALA  2011  20.5   45.7   24.100000  165.2  124.2   788.5
# 3998             KERALA  2012   7.4   11.0   21.000000  171.1   95.3   430.3
# 3999             KERALA  2013   3.9   40.1   49.900000   49.3  119.3  1042.7
# 4000             KERALA  2014   4.6   10.3   17.900000   95.7  251.0   454.4
# 4001             KERALA  2015   3.1    5.8   50.100000  214.1  201.8   563.6
#
# ...

# %%
A.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JAN                 0
# FEB                 0
# MAR                 0
# APR                 0
# MAY                 0
# JUN                 0
# JUL                 0
# AUG                 0
# SEP                 0
# OCT                 0
# NOV                 0
# DEC                 0
# JJAS                0
# OND                 0
# ANNUAL_RAIN_fall    0
# dtype: int64

# %%
daata=A.filter(['SUBDIVISION','YEAR','JJAS','OND','ANNUAL_RAIN_fall'],axis=1)
daata
# Out:
#             SUBDIVISION  YEAR         JJAS         OND  ANNUAL_RAIN_fall
# 110   ARUNACHAL PRADESH  1916  2783.044792  254.885263       3967.630055
# 111   ARUNACHAL PRADESH  1917  2772.800000  262.800000       3752.527368
# 112   ARUNACHAL PRADESH  1918  4121.300000  146.700000       5486.300000
# 113   ARUNACHAL PRADESH  1919  2888.000000  997.600000       4693.900000
# 114   ARUNACHAL PRADESH  1920  2649.200000  103.300000       4106.700000
# ...                 ...   ...          ...         ...               ...
# 3997             KERALA  2011  2209.200000  446.400000       3035.300000
# 3998             KERALA  2012  1535.600000  309.800000       2151.200000
# 3999             KERALA  2013  2561.200000  431.800000       3255.500000
# 4000             KERALA  2014  2164.900000  502.200000       3046.600000
# 4001             KERALA  2015  1514.700000  611.100000       2600.700000
#
# [442 rows x 5 columns]

# %%
daata.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JJAS                0
# OND                 0
# ANNUAL_RAIN_fall    0
# dtype: int64

# %%
daata.to_csv('rain.csv')
daata
# Out:
#             SUBDIVISION  YEAR         JJAS         OND  ANNUAL_RAIN_fall
# 110   ARUNACHAL PRADESH  1916  2783.044792  254.885263       3967.630055
# 111   ARUNACHAL PRADESH  1917  2772.800000  262.800000       3752.527368
# 112   ARUNACHAL PRADESH  1918  4121.300000  146.700000       5486.300000
# 113   ARUNACHAL PRADESH  1919  2888.000000  997.600000       4693.900000
# 114   ARUNACHAL PRADESH  1920  2649.200000  103.300000       4106.700000
# ...                 ...   ...          ...         ...               ...
# 3997             KERALA  2011  2209.200000  446.400000       3035.300000
# 3998             KERALA  2012  1535.600000  309.800000       2151.200000
# 3999             KERALA  2013  2561.200000  431.800000       3255.500000
# 4000             KERALA  2014  2164.900000  502.200000       3046.600000
# 4001             KERALA  2015  1514.700000  611.100000       2600.700000
#
# [442 rows x 5 columns]
